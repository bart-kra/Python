# %% [markdown]
# <a href="https://colab.research.google.com/github/bart-kra/Python/blob/main/center_of_gravity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
def computing(m, h, l, part):
  m_fac = [6.94, 43.457, 1.707, 1.625, 0.614, 14.165, 4.33, 1.371]
  rad_fac = [50, 44.5, 45, 42.7, 37, 45.5, 40.5, 44.1]

  df = pd.DataFrame()

  df['segment'] = part
  df['l_segment'] = l
  df['m_fac'] = m_fac 
  df['rad_fac'] = rad_fac 
  df['m_rel'] = df['m_fac'] * m * 0.01
  df['r'] = df['segment'] * df['rad_fac'] * 0.01

  return df

# %%
# part = ['glowa', 'tulow', 'ramie', 'przedramie', 'dlon', 'udo', 'podudzie', 'stopa']

# print('Masa ciała: ', end='')
# m = int(input())
# print('Wzrost: ', end='')
# h = int(input())

# l = []

# for i in part:
#   print('l_{}: '.format(i), end='')
#   l.append(int(input()))

df = computing(m, h, l, part)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...

# %%
df[['m_rel', 'r']] = df[['m_rel', 'r']].apply(lambda x: round(x, 2))

# %%
df
# Out:
#          part  l_part   m_fac  rad_fac  m_rel      r
# 0       glowa      30   6.940     50.0   4.79  15.00
# 1       tulow      53  43.457     44.5  29.99  23.58
# 2       ramie      31   1.707     45.0   1.18  13.95
# 3  przedramie      27   1.625     42.7   1.12  11.53
# 4        dlon      20   0.614     37.0   0.42   7.40
# 5         udo      41  14.165     45.5   9.77  18.66
# 6    podudzie      42   4.330     40.5   2.99  17.01
# 7       stopa      25   1.371     44.1   0.95  11.02

# %%
itrt = 1
m_list = []
for i, j, k in zip(df['part'], df['m_rel'], df['r']):
  print('{}: \nm_{} = {}'.format(i, itrt, round(j, 2)))
  print('r_{} = {}\n'.format(itrt, round(k, 2)))
  itrt += 1
  m_list.append(round(j, 2))
print(m_list)
# Out:
# glowa:
# m_1 = 4.79
# r_1 = 15.0
#
# tulow:
# m_2 = 29.99
# r_2 = 23.59
#
# ramie:
# m_3 = 1.18
# r_3 = 13.95
#
# przedramie:
# m_4 = 1.12
# r_4 = 11.53
#
# dlon:
# m_5 = 0.42
# r_5 = 7.4
#
# udo:
# m_6 = 9.77
# r_6 = 18.66
#
# podudzie:
# m_7 = 2.99
# r_7 = 17.01
#
# stopa:
# m_8 = 0.95
# r_8 = 11.03
#
# [4.79, 29.99, 1.18, 1.12, 0.42, 9.77, 2.99, 0.95]

# %%
r_list_x = [161,116.5,142,141.5,141,74.3,35,5.5]
r_list_y = [9,12.5,14,41.5,64.5,10,8,11]

df1 = pd.DataFrame()
df1['part'] = df['part']
df1['r_x1'] = r_list_x
df1['r_y1'] = r_list_y
df1['m_rel'] = df['m_rel']
df1['seg_count'] = [1, 1, 2, 2, 2, 2, 2, 2]
df1['m_rel*r_x1*seg_count'] = df1['r_x1'] * df1['m_rel'] * df1['seg_count']
df1['m_rel*r_y1*seg_count'] = df1['r_y1'] * df1['m_rel'] * df1['seg_count']

df1
# Out:
#          part   r_x1  r_y1  m_rel  seg_count  m_rel*r_x1*seg_count  \
# 0       glowa  161.0   9.0   4.79          1               771.190
# 1       tulow  116.5  12.5  29.99          1              3493.835
# 2       ramie  142.0  14.0   1.18          2               335.120
# 3  przedramie  141.5  41.5   1.12          2               316.960
# 4        dlon  141.0  64.5   0.42          2               118.440
# 5         udo   74.3  10.0   9.77          2              1451.822
# 6    podudzie   35.0   8.0   2.99          2               209.300
# 7       stopa    5.5  11.0   0.95          2                10.450
#
#    m_rel*r_y1*seg_count
# 0                43.110
# 1               374.875
# 2                33.040
# 3                92.960
# 4                54.180
# 5               195.400
# 6                47.840
# 7                20.900

# %%
liczx = round(df1['m_rel*r_x1*seg_count'].sum(),2)
mianx = round(df1['m_rel'].sum(), 2)
print('x1 = {}'.format(liczx/mianx))
liczy = round(df1['m_rel*r_y1*seg_count'].sum(),2)
miany = round(df1['m_rel'].sum(), 2)
print('y1 = {}'.format(liczy/miany))
# Out:
# x1 = 130.97285686389375
# y1 = 16.83850810388596

# %%
r_list_x1 = [161,116.5,142,141.5,138,74.3,35,5.5]
r_list_y1 = [9,12.5,14,41.5,65.5,10,8,11]

df2 = pd.DataFrame()
df2['part'] = df['part']
df2['r_x2'] = r_list_x1
df2['r_y2'] = r_list_y1
df2['m_rel'] = df['m_rel']
df2['seg_count'] = [1, 1, 2, 2, 1, 2, 2, 2]
df2['m_rel*r_x2*seg_count'] = df2['r_x2'] * df2['m_rel'] * df2['seg_count']
df2['m_rel*r_y2*seg_count'] = df2['r_y2'] * df2['m_rel'] * df2['seg_count']

df2.loc[4, 'm_rel'] = 11
df2.loc[4, 'part'] = 'obciazenie'

df2
# Out:
#          part   r_x2  r_y2  m_rel  seg_count  m_rel*r_x2*seg_count  \
# 0       glowa  161.0   9.0   4.79          1               771.190
# 1       tulow  116.5  12.5  29.99          1              3493.835
# 2       ramie  142.0  14.0   1.18          2               335.120
# 3  przedramie  141.5  41.5   1.12          2               316.960
# 4  obciazenie  138.0  65.5  11.00          1                57.960
# 5         udo   74.3  10.0   9.77          2              1451.822
# 6    podudzie   35.0   8.0   2.99          2               209.300
# 7       stopa    5.5  11.0   0.95          2                10.450
#
#    m_rel*r_y2*seg_count
# 0                43.110
# 1               374.875
# 2                33.040
# 3                92.960
# 4                27.510
# 5               195.400
# 6                47.840
# 7                20.900

# %%
liczx1 = round(df2['m_rel*r_x2*seg_count'].sum(),2)
mianx1 = round(df2['m_rel'].sum(), 2)
print('x2 = {}'.format(liczx1/mianx1))
liczy1 = round(df2['m_rel*r_y2*seg_count'].sum(),2)
miany1 = round(df2['m_rel'].sum(), 2)
print('y2 = {}'.format(liczy1/miany1))
# Out:
# x2 = 107.56821492150834
# y2 = 13.523871176565788

# %%
r_list_x2 = [9,12.5,5,4.5,4,10,8,11]
r_list_y2 = [15,59.5,44,71.5,94.5,101.7,141,171.5]

df3 = pd.DataFrame()
df3['part'] = df['part']
df3['r_x3'] = r_list_x2
df3['r_y3'] = r_list_y2
df3['m_rel'] = df['m_rel']
df3['seg_count'] = [1, 1, 2, 2, 2, 2, 2, 2]
df3['m_rel*r_x3*seg_count'] = df3['r_x3'] * df3['m_rel'] * df3['seg_count']
df3['m_rel*r_y3*seg_count'] = df3['r_y3'] * df3['m_rel'] * df3['seg_count']

df3
# Out:
#          part  r_x3   r_y3  m_rel  seg_count  m_rel*r_x3*seg_count  \
# 0       glowa   9.0   15.0   4.79          1                43.110
# 1       tulow  12.5   59.5  29.99          1               374.875
# 2       ramie   5.0   44.0   1.18          2                11.800
# 3  przedramie   4.5   71.5   1.12          2                10.080
# 4        dlon   4.0   94.5   0.42          2                 3.360
# 5         udo  10.0  101.7   9.77          2               195.400
# 6    podudzie   8.0  141.0   2.99          2                47.840
# 7       stopa  11.0  171.5   0.95          2                20.900
#
#    m_rel*r_y3*seg_count
# 0                71.850
# 1              1784.405
# 2               103.840
# 3               160.160
# 4                79.380
# 5              1987.218
# 6               843.180
# 7               325.850

# %%
liczx2 = round(df3['m_rel*r_x3*seg_count'].sum(),2)
mianx2 = round(df3['m_rel'].sum(), 2)
print('x3 = {}'.format(liczx2/mianx2))
liczy2 = round(df3['m_rel*r_y3*seg_count'].sum(),2)
miany2 = round(df3['m_rel'].sum(), 2)
print('y3 = {}'.format(liczy2/miany2))
# Out:
# x3 = 13.812927162663541
# y3 = 104.58660417887131
