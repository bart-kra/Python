# %%
# !pip install phonenumbers
# !pip install opencage
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: phonenumbers in /usr/local/lib/python3.9/dist-packages (8.13.7)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencage in /usr/local/lib/python3.9/dist-packages (2.1.0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from opencage) (2.2.1)
# Requirement already satisfied: pyopenssl>=0.15.1 in /usr/local/lib/python3.9/dist-packages (from opencage) (23.0.0)
# Requirement already satisfied: Requests>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from opencage) (2.27.1)
# Requirement already satisfied: cryptography<40,>=38.0.0 in /usr/local/lib/python3.9/dist-packages (from pyopenssl>=0.15.1->opencage) (39.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from Requests>=2.2.0->opencage) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from Requests>=2.2.0->opencage) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from Requests>=2.2.0->opencage) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from Requests>=2.2.0->opencage) (1.26.15)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography<40,>=38.0.0->pyopenssl>=0.15.1->opencage) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography<40,>=38.0.0->pyopenssl>=0.15.1->opencage) (2.21)

# %%
import phonenumbers
import folium
import opencage
from phonenumbers import geocoder
from phonenumbers import carrier
from opencage.geocoder import OpenCageGeocode

# %%
api_key = 'c174be2dca3c4d8794a2ce1dc626ba4d'
geocoder = OpenCageGeocode(api_key)
number = '+721374648'
parsed_number = phonenumbers.parse(number)

# %%
location = geocoder.description_for_number(parsed_number, 'pl')
# service_provider = carrier.name_for_number(parsed_number, 'pl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-35a8bc448f2a> in <module>
# ----> 1 location = geocoder.description_for_number(parsed_number, 'pl')
#       2 # service_provider = carrier.name_for_number(parsed_number, 'pl')
#
# AttributeError: 'OpenCageGeocode' object has no attribute 'description_for_number'

# %%
result = geocoder.geocode(location)
lat = result[0]['geometry']['lat']
lng = result[0]['geometry']['lng']
print(lat, lng)
# Out:
# 52.215933 19.134422

# %%
52.215933 19.134422
# Out:
# [{'annotations': {'DMS': {'lat': "52° 12' 57.35880'' N",
#     'lng': "19° 8' 3.91920'' E"},
#    'MGRS': '34UCC7254986695',
#    'Maidenhead': 'JO92nf61dt',
#    'Mercator': {'x': 2130034.114, 'y': 6805471.267},
#    'NUTS': {'NUTS0': {'code': 'PL'},
#     'NUTS1': {'code': 'PL7'},
#     'NUTS2': {'code': 'PL71'},
#     'NUTS3': {'code': 'PL715'}},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?relation=49715#map=16/52.21593/19.13442',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/52.21593/19.13442&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=52.21593&mlon=19.13442#map=16/52.21593/19.13442'},
#    'UN_M49': {'regions': {'EASTERN_EUROPE': '151',
#      'EUROPE': '150',
#      'PL': '616',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 48,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': ',',
#     'format': '%n %u',
#     'html_entity': 'z&#322;',
#     'iso_code': 'PLN',
#     'iso_numeric': '985',
#     'name': 'Polish Złoty',
#     'smallest_denomination': 1,
#     'subunit': 'Grosz',
#     'subunit_to_unit': 100,
#     'symbol': 'zł',
#     'symbol_first': 0,
#     'thousands_separator': ' '},
#    'flag': '🇵🇱',
#    'geohash': 'u3m953t7b77jhbhp6164',
#    'qibla': 144.7,
#    'roadinfo': {'drive_on': 'right', 'speed_in': 'km/h'},
#    'sun': {'rise': {'apparent': 1679287680,
#      'astronomical': 1679280780,
#      'civil': 1679285640,
#      'nautical': 1679283300},
#     'set': {'apparent': 1679331300,
#      'astronomical': 1679338200,
#      'civil': 1679333340,
#      'nautical': 1679335740}},
#    'timezone': {'name': 'Europe/Warsaw',
#     'now_in_dst': 0,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'CET'},
#    'what3words': {'words': 'lambing.smaller.sunscreen'},
#    'wikidata': 'Q36'},
#   'bounds': {'northeast': {'lat': 55.03605, 'lng': 24.145783},
#    'southwest': {'lat': 49.0020468, 'lng': 14.0696389}},
#   'components': {'ISO_3166-1_alpha-2': 'PL',
#    'ISO_3166-1_alpha-3': 'POL',
#    '_category': 'place',
#    '_type': 'country',
#    'continent': 'Europe',
#    'country': 'Poland',
#    'country_code': 'pl',
#    'political_union': 'European Union'},
#   'confidence': 1,
#   'formatted': 'Poland',
#   'geometry': {'lat': 52.215933, 'lng': 19.134422}},
#  {'annotations': {'DMS': {'lat': "49° 47' 57.79932'' N",
#     'lng': "19° 13' 31.02816'' E"},
#    'MGRS': '34UCA7228617837',
#    'Maidenhead': 'JN99ot71au',
#    'Mercator': {'x': 2140149.003, 'y': 6378951.139},
#    'NUTS': {'NUTS0': {'code': 'PL'},
#     'NUTS1': {'code': 'PL2'},
#     'NUTS2': {'code': 'PL22'},
#     'NUTS3': {'code': 'PL225'}},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=3009741322#map=16/49.79939/19.22529',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/49.79939/19.22529&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=49.79939&mlon=19.22529#map=16/49.79939/19.22529'},
#    'UN_M49': {'regions': {'EASTERN_EUROPE': '151',
#      'EUROPE': '150',
#      'PL': '616',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 48,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': ',',
#     'format': '%n %u',
#     'html_entity': 'z&#322;',
#     'iso_code': 'PLN',
#     'iso_numeric': '985',
#     'name': 'Polish Złoty',
#     'smallest_denomination': 1,
#     'subunit': 'Grosz',
#     'subunit_to_unit': 100,
#     'symbol': 'zł',
#     'symbol_first': 0,
#     'thousands_separator': ' '},
#    'flag': '🇵🇱',
#    'geohash': 'u2vem3xqmwguyb6677vg',
#    'qibla': 142.69,
#    'roadinfo': {'drive_on': 'right', 'speed_in': 'km/h'},
#    'sun': {'rise': {'apparent': 1679287680,
#      'astronomical': 1679281140,
#      'civil': 1679285760,
#      'nautical': 1679283480},
#     'set': {'apparent': 1679331240,
#      'astronomical': 1679337780,
#      'civil': 1679333160,
#      'nautical': 1679335440}},
#    'timezone': {'name': 'Europe/Warsaw',
#     'now_in_dst': 0,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'CET'},
#    'what3words': {'words': 'handier.espresso.collides'}},
#   'bounds': {'northeast': {'lat': 49.8193887, 'lng': 19.2452856},
#    'southwest': {'lat': 49.7793887, 'lng': 19.2052856}},
#   'components': {'ISO_3166-1_alpha-2': 'PL',
#    'ISO_3166-1_alpha-3': 'POL',
#    'ISO_3166-2': ['PL-24'],
#    '_category': 'place',
#    '_type': 'hamlet',
#    'continent': 'Europe',
#    'country': 'Poland',
#    'country_code': 'pl',
#    'county': 'Bielsko County',
#    'hamlet': 'Polska',
#    'municipality': 'gmina Porąbka',
#    'political_union': 'European Union',
#    'postcode': '43-353',
#    'state': 'Silesian Voivodeship',
#    'state_code': '24',
#    'village': 'Kozubnik'},
#   'confidence': 7,
#   'formatted': '43-353 Kozubnik, Poland',
#   'geometry': {'lat': 49.7993887, 'lng': 19.2252856}},
#  {'annotations': {'DMS': {'lat': "49° 59' 22.99992'' N",
#     'lng': "21° 28' 14.99988'' E"},
#    'MGRS': '34UEA3375037594',
#    'Maidenhead': 'KN09rx67mm',
#    'Mercator': {'x': 2390122.23, 'y': 6411749.794},
#    'NUTS': {'NUTS0': {'code': 'PL'},
#     'NUTS1': {'code': 'PL8'},
#     'NUTS2': {'code': 'PL82'},
#     'NUTS3': {'code': 'PL823'}},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=3009741323#map=16/49.98972/21.47083',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/49.98972/21.47083&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=49.98972&mlon=21.47083#map=16/49.98972/21.47083'},
#    'UN_M49': {'regions': {'EASTERN_EUROPE': '151',
#      'EUROPE': '150',
#      'PL': '616',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 48,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': ',',
#     'format': '%n %u',
#     'html_entity': 'z&#322;',
#     'iso_code': 'PLN',
#     'iso_numeric': '985',
#     'name': 'Polish Złoty',
#     'smallest_denomination': 1,
#     'subunit': 'Grosz',
#     'subunit_to_unit': 100,
#     'symbol': 'zł',
#     'symbol_first': 0,
#     'thousands_separator': ' '},
#    'flag': '🇵🇱',
#    'geohash': 'u2zk2s6e4xtsq400pv8y',
#    'qibla': 146.44,
#    'roadinfo': {'drive_on': 'right', 'speed_in': 'km/h'},
#    'sun': {'rise': {'apparent': 1679287140,
#      'astronomical': 1679280600,
#      'civil': 1679285220,
#      'nautical': 1679282940},
#     'set': {'apparent': 1679330700,
#      'astronomical': 1679337300,
#      'civil': 1679332680,
#      'nautical': 1679334960}},
#    'timezone': {'name': 'Europe/Warsaw',
#     'now_in_dst': 0,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'CET'},
#    'what3words': {'words': 'daffodil.tissues.atoning'}},
#   'bounds': {'northeast': {'lat': 50.0097222, 'lng': 21.4908333},
#    'southwest': {'lat': 49.9697222, 'lng': 21.4508333}},
#   'components': {'ISO_3166-1_alpha-2': 'PL',
#    'ISO_3166-1_alpha-3': 'POL',
#    'ISO_3166-2': ['PL-18'],
#    '_category': 'place',
#    '_type': 'hamlet',
#    'continent': 'Europe',
#    'country': 'Poland',
#    'country_code': 'pl',
#    'county': 'Ropczyce-Sędziszów County',
#    'hamlet': 'Polska',
#    'municipality': 'gmina Ropczyce',
#    'political_union': 'European Union',
#    'postcode': '39-107',
#    'state': 'Subcarpathian Voivodeship',
#    'state_code': '18',
#    'village': 'Niedźwiada'},
#   'confidence': 7,
#   'formatted': '39-107 Niedźwiada, Poland',
#   'geometry': {'lat': 49.9897222, 'lng': 21.4708333}},
#  {'annotations': {'DMS': {'lat': "50° 29' 16.72908'' N",
#     'lng': "19° 38' 55.87332'' E"},
#    'MGRS': '34UDA0415293760',
#    'Maidenhead': 'JO90tl77uc',
#    'Mercator': {'x': 2187300.389, 'y': 6498233.547},
#    'NUTS': {'NUTS0': {'code': 'PL'},
#     'NUTS1': {'code': 'PL2'},
#     'NUTS2': {'code': 'PL22'},
#     'NUTS3': {'code': 'PL22B'}},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=3009741324#map=16/50.48798/19.64885',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/50.48798/19.64885&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=50.48798&mlon=19.64885#map=16/50.48798/19.64885'},
#    'UN_M49': {'regions': {'EASTERN_EUROPE': '151',
#      'EUROPE': '150',
#      'PL': '616',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 48,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': ',',
#     'format': '%n %u',
#     'html_entity': 'z&#322;',
#     'iso_code': 'PLN',
#     'iso_numeric': '985',
#     'name': 'Polish Złoty',
#     'smallest_denomination': 1,
#     'subunit': 'Grosz',
#     'subunit_to_unit': 100,
#     'symbol': 'zł',
#     'symbol_first': 0,
#     'thousands_separator': ' '},
#    'flag': '🇵🇱',
#    'geohash': 'u2vzpp5cg3xjxkgeggxt',
#    'qibla': 143.99,
#    'roadinfo': {'drive_on': 'right', 'speed_in': 'km/h'},
#    'sun': {'rise': {'apparent': 1679287560,
#      'astronomical': 1679280960,
#      'civil': 1679285640,
#      'nautical': 1679283360},
#     'set': {'apparent': 1679331180,
#      'astronomical': 1679337780,
#      'civil': 1679333100,
#      'nautical': 1679335440}},
#    'timezone': {'name': 'Europe/Warsaw',
#     'now_in_dst': 0,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'CET'},
#    'what3words': {'words': 'reminders.stamina.thanking'},
#    'wikidata': 'Q18424791'},
#   'bounds': {'northeast': {'lat': 50.5079803, 'lng': 19.6688537},
#    'southwest': {'lat': 50.4679803, 'lng': 19.6288537}},
#   'components': {'ISO_3166-1_alpha-2': 'PL',
#    'ISO_3166-1_alpha-3': 'POL',
#    'ISO_3166-2': ['PL-24'],
#    '_category': 'place',
#    '_type': 'hamlet',
#    'continent': 'Europe',
#    'country': 'Poland',
#    'country_code': 'pl',
#    'county': 'Zawiercie County',
#    'hamlet': 'Polska',
#    'municipality': 'gmina Pilica',
#    'political_union': 'European Union',
#    'postcode': '42-436',
#    'state': 'Silesian Voivodeship',
#    'state_code': '24',
#    'village': 'Dzwonowice'},
#   'confidence': 7,
#   'formatted': '42-436 Dzwonowice, Poland',
#   'geometry': {'lat': 50.4879803, 'lng': 19.6488537}},
#  {'annotations': {'DMS': {'lat': "52° 12' 28.70208'' N",
#     'lng': "21° 4' 32.14560'' E"},
#    'MGRS': '34UEC0516584172',
#    'Maidenhead': 'KO02me99bv',
#    'Mercator': {'x': 2346124.615, 'y': 6804028.754},
#    'NUTS': {'NUTS0': {'code': 'PL'},
#     'NUTS1': {'code': 'PL9'},
#     'NUTS2': {'code': 'PL91'},
#     'NUTS3': {'code': 'PL912'}},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=23455706#map=16/52.20797/21.07560',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/52.20797/21.07560&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=52.20797&mlon=21.07560#map=16/52.20797/21.07560'},
#    'UN_M49': {'regions': {'EASTERN_EUROPE': '151',
#      'EUROPE': '150',
#      'PL': '616',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 48,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': ',',
#     'format': '%n %u',
#     'html_entity': 'z&#322;',
#     'iso_code': 'PLN',
#     'iso_numeric': '985',
#     'name': 'Polish Złoty',
#     'smallest_denomination': 1,
#     'subunit': 'Grosz',
#     'subunit_to_unit': 100,
#     'symbol': 'zł',
#     'symbol_first': 0,
#     'thousands_separator': ' '},
#    'flag': '🇵🇱',
#    'geohash': 'u3qcp84v2zx2sdjfpf26',
#    'qibla': 147.67,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Polska',
#     'road_type': 'tertiary',
#     'speed_in': 'km/h'},
#    'sun': {'rise': {'apparent': 1679287200,
#      'astronomical': 1679280300,
#      'civil': 1679285220,
#      'nautical': 1679282820},
#     'set': {'apparent': 1679330820,
#      'astronomical': 1679337780,
#      'civil': 1679332860,
#      'nautical': 1679335260}},
#    'timezone': {'name': 'Europe/Warsaw',
#     'now_in_dst': 0,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'CET'},
#    'what3words': {'words': 'october.diamonds.adopt'}},
#   'bounds': {'northeast': {'lat': 52.2087551, 'lng': 21.0777541},
#    'southwest': {'lat': 52.2053382, 'lng': 21.0744917}},
#   'components': {'ISO_3166-1_alpha-2': 'PL',
#    'ISO_3166-1_alpha-3': 'POL',
#    'ISO_3166-2': ['PL-14'],
#    '_category': 'road',
#    '_type': 'road',
#    'city': 'Warsaw',
#    'city_block': 'Osiedle Siekierki',
#    'continent': 'Europe',
#    'country': 'Poland',
#    'country_code': 'pl',
#    'political_union': 'European Union',
#    'postcode': '00-703',
#    'quarter': 'Siekierki',
#    'road': 'Polska',
#    'road_type': 'tertiary',
#    'state': 'Masovian Voivodeship',
#    'state_code': '14',
#    'suburb': 'Mokotów'},
#   'confidence': 9,
#   'formatted': 'Polska, 00-703 Warsaw, Poland',
#   'geometry': {'lat': 52.2079728, 'lng': 21.075596}},
#  {'annotations': {'DMS': {'lat': "52° 25' 16.26024'' N",
#     'lng': "16° 52' 24.28428'' E"},
#    'MGRS': '33UXU2739409535',
#    'Maidenhead': 'JO82kk41tc',
#    'Mercator': {'x': 1878339.665, 'y': 6842755.942},
#    'NUTS': {'NUTS0': {'code': 'PL'},
#     'NUTS1': {'code': 'PL4'},
#     'NUTS2': {'code': 'PL41'},
#     'NUTS3': {'code': 'PL415'}},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=636616974#map=16/52.42118/16.87341',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/52.42118/16.87341&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=52.42118&mlon=16.87341#map=16/52.42118/16.87341'},
#    'UN_M49': {'regions': {'EASTERN_EUROPE': '151',
#      'EUROPE': '150',
#      'PL': '616',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 48,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': ',',
#     'format': '%n %u',
#     'html_entity': 'z&#322;',
#     'iso_code': 'PLN',
#     'iso_numeric': '985',
#     'name': 'Polish Złoty',
#     'smallest_denomination': 1,
#     'subunit': 'Grosz',
#     'subunit_to_unit': 100,
#     'symbol': 'zł',
#     'symbol_first': 0,
#     'thousands_separator': ' '},
#    'flag': '🇵🇱',
#    'geohash': 'u37fpyyze0b5k48n4qv1',
#    'qibla': 141.51,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Polska',
#     'road_type': 'tertiary',
#     'speed_in': 'km/h'},
#    'sun': {'rise': {'apparent': 1679288220,
#      'astronomical': 1679281320,
#      'civil': 1679286180,
#      'nautical': 1679283780},
#     'set': {'apparent': 1679331840,
#      'astronomical': 1679338800,
#      'civil': 1679333880,
#      'nautical': 1679336280}},
#    'timezone': {'name': 'Europe/Warsaw',
#     'now_in_dst': 0,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'CET'},
#    'what3words': {'words': 'tourist.searches.stores'}},
#   'bounds': {'northeast': {'lat': 52.4212329, 'lng': 16.8734773},
#    'southwest': {'lat': 52.4211091, 'lng': 16.8733469}},
#   'components': {'ISO_3166-1_alpha-2': 'PL',
#    'ISO_3166-1_alpha-3': 'POL',
#    'ISO_3166-2': ['PL-30'],
#    '_category': 'road',
#    '_type': 'road',
#    'city': 'Poznań',
#    'continent': 'Europe',
#    'country': 'Poland',
#    'country_code': 'pl',
#    'political_union': 'European Union',
#    'postcode': '60-594',
#    'road': 'Polska',
#    'road_type': 'tertiary',
#    'state': 'Greater Poland Voivodeship',
#    'state_code': '30',
#    'suburb': 'Wola'},
#   'confidence': 9,
#   'formatted': 'Polska, 60-594 Poznań, Poland',
#   'geometry': {'lat': 52.4211834, 'lng': 16.8734123}},
#  {'annotations': {'DMS': {'lat': "52° 24' 43.70472'' N",
#     'lng': "16° 52' 10.69212'' E"},
#    'MGRS': '33UXU2716308523',
#    'Maidenhead': 'JO82kj48iv',
#    'Mercator': {'x': 1877919.367, 'y': 6841109.536},
#    'NUTS': {'NUTS0': {'code': 'PL'},
#     'NUTS1': {'code': 'PL4'},
#     'NUTS2': {'code': 'PL41'},
#     'NUTS3': {'code': 'PL415'}},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=16429966#map=16/52.41214/16.86964',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/52.41214/16.86964&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=52.41214&mlon=16.86964#map=16/52.41214/16.86964'},
#    'UN_M49': {'regions': {'EASTERN_EUROPE': '151',
#      'EUROPE': '150',
#      'PL': '616',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 48,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': ',',
#     'format': '%n %u',
#     'html_entity': 'z&#322;',
#     'iso_code': 'PLN',
#     'iso_numeric': '985',
#     'name': 'Polish Złoty',
#     'smallest_denomination': 1,
#     'subunit': 'Grosz',
#     'subunit_to_unit': 100,
#     'symbol': 'zł',
#     'symbol_first': 0,
#     'thousands_separator': ' '},
#    'flag': '🇵🇱',
#    'geohash': 'u37fpvk4g50fd9mwj3p3',
#    'qibla': 141.5,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Polska',
#     'road_type': 'tertiary',
#     'speed_in': 'km/h'},
#    'sun': {'rise': {'apparent': 1679288220,
#      'astronomical': 1679281320,
#      'civil': 1679286180,
#      'nautical': 1679283780},
#     'set': {'apparent': 1679331840,
#      'astronomical': 1679338800,
#      'civil': 1679333880,
#      'nautical': 1679336280}},
#    'timezone': {'name': 'Europe/Warsaw',
#     'now_in_dst': 0,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'CET'},
#    'what3words': {'words': 'square.tens.chambers'}},
#   'bounds': {'northeast': {'lat': 52.4122718, 'lng': 16.869682},
#    'southwest': {'lat': 52.4121402, 'lng': 16.8696367}},
#   'components': {'ISO_3166-1_alpha-2': 'PL',
#    'ISO_3166-1_alpha-3': 'POL',
#    'ISO_3166-2': ['PL-30'],
#    '_category': 'road',
#    '_type': 'road',
#    'city': 'Poznań',
#    'continent': 'Europe',
#    'country': 'Poland',
#    'country_code': 'pl',
#    'neighbourhood': 'Osiedle Ognik',
#    'political_union': 'European Union',
#    'postcode': '60-393',
#    'quarter': 'Świt',
#    'road': 'Polska',
#    'road_type': 'tertiary',
#    'state': 'Greater Poland Voivodeship',
#    'state_code': '30',
#    'suburb': 'Grunwald Północ'},
#   'confidence': 9,
#   'formatted': 'Polska, 60-393 Poznań, Poland',
#   'geometry': {'lat': 52.4121402, 'lng': 16.8696367}}]
